# %%
import warnings
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")
import requests
from bs4 import BeautifulSoup
import selenium
from selenium import webdriver
import pandas as pd
import time
from selenium.common.exceptions import NoSuchElementException, StaleElementReferenceException, ElementClickInterceptedException

# %%
url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
driver.get(url)
driver.maximize_window()
driver.find_element_by_xpath("//b").click()
records = []
for row in driver.find_elements_by_xpath("(//table[@class='wikitable sortable jquery-tablesorter'])[1]//tr")[1:-1]:
    temp = ''
    for element in row.find_elements_by_xpath(".//td"):        
        temp += element.text + '|'
    records.append(temp.split('|')[:-2])

df = pd.DataFrame(records, columns=['Rank', 'Video_Name', 'Artist_Name', 'Views_in_Billions', 'Upload_Date'])

arranged_cols = ['Rank', 'Video_Name', 'Artist_Name', 'Upload_Date', 'Views_in_Billions']

df.Video_Name = df.Video_Name.apply(lambda x:x[:-4].strip('"'))
df = df[arranged_cols]
df
# Out:
# Legality Response number from our URL is: <Response [200]>
#    Rank                                 Video_Name  \
# 0    1.                           Baby Shark Dance
# 1    2.                                  Despacito
# 2    3.                       Johny Johny Yes Papa
# 3    4.                               Shape of You
# 4    5.                              See You Again
# 5    6.                                  Bath Song
# 6    7.  Learning Colors – Colorful Eggs on a Farm
# 7    8.   Masha and the Bear – Recipe for Disaster
# 8    9.                                Uptown Funk
# 9   10.                Phonics Song with Two Words
# 10  11.                              Gangnam Style
# 11  12.                             Dame Tu Cosita
# 12  13.                                      Sugar
# 13  14.                                      Sorry
# 14  15.                                       Roar
# 15  16.                          Wheels on the Bus
# ...

# %%
url = "https://www.bcci.tv/"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
driver.get(url)
driver.maximize_window()

#clickin on International tab
driver.find_element_by_xpath("//li[@class='nav-item ml-0']").click()

'''#clicking on Fixtures
driver.find_element_by_xpath("//a[@class='nav-link active']").click()'''

# Empty lists
match_title=[]
series=[]
place=[]
date=[]
matchtime=[]
date=[]
time=[]
for i in driver.find_elements_by_xpath("//span[@class='ng-binding']"):
    match_title.append(i.text)
    
'''for i in driver.find_elements_by_xpath("//div[@class='fix-place ng-binding ng-scope]"):
    series.append(i.text.strip())
'''
for i in driver.find_elements_by_xpath("//div[@class='fixture__description u-unskewed-text']/p/span"):
    place.append(i.text)
    
for i in driver.find_elements_by_xpath("//div[@class='match-card-left match-schedule']"):
    date.append(i.text)
for i in driver.find_elements_by_xpath("//div[@class='match-card-right match-schedule']"):
    date.append(i.text)


# Creating data frame
matches_data=pd.DataFrame({'Match Title': match_title,
                          "Series": series,
                          "Place": place,
                          "Date": date,
                          "Time": matchtime})
matches_data
# Out:
# Legality Response number from our URL is: <Response [200]>
# Empty DataFrame
# Columns: [Match Title, Series, Place, Date, Time]
# Index: []

# %%
url = "https://www.guru99.com/"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
driver.get(url)
driver.maximize_window()

error = driver.find_element_by_xpath('//*[@id="java_technologies"]/li[3]/a').get_attribute('href')
driver.get(error)

exception = driver.find_element_by_xpath('/html/body/div[1]/div/div/div/main/div/article/div/div/table[5]/tbody/tr[34]/td[1]/a').get_attribute('href')
driver.get(exception)

Data = []
table = driver.find_elements_by_xpath("//table[@class='table table-striped']//td")
for i in table:
    try:
        Data.append(i.text)
    except NoSuchElementException:
        Data.append('-')

Name = []
for i in range(2,len(Data),2):
    Name.append(Data[i])

Description = []
for i in range(3,len(Data),2):
    Description.append(Data[i])

df=pd.DataFrame({"Exception name": Name, "Exception description": Description})
df
# Out:
# Legality Response number from our URL is: <Response [403]>
#                          Exception name  \
# 0         ElementNotSelectableException
# 1                NoSuchElementException
# 2                  NoSuchFrameException
# 3               NoAlertPresentException
# 4                 NoSuchWindowException
# 5        StaleElementReferenceException
# 6              SessionNotFoundException
# 7                      TimeoutException
# 8                    WebDriverException
# 9             ConnectionClosedException
# 10     ElementClickInterceptedException
# 11      ElementNotInteractableException
# 12             ErrorInResponseException
# 13  ErrorHandler.UnknownServerException
# 14         ImeActivationFailedException
# 15             ImeNotAvailableException
# 16         InsecureCertificateException
# 17             InvalidArgumentException
# 18         InvalidCookieDomainException
# 19          InvalidCoordinatesException
# 20          InvalidElementStateExceptio
# ...

# %%
url = "https://statisticstimes.com/"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
driver.get(url)
driver.maximize_window()

link1=driver.find_element_by_xpath("//div[@class='dropdown-content']/a[3]").get_attribute("href")
print(link1)
driver.get(link1)
driver.get("https://statisticstimes.com/economy/india/indian-states-gdp.php")


ranklist=[]
statelist=[]
gsdplist1=[]
gsdplist2=[]
sharelist=[]
gdplist=[]
#getting rank
rank=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[1]")
for i in rank:
    #print(i.text)
    ranklist.append(i.text)

#getting state
state=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[2]")
for i in state:
    #print(i.text)
    statelist.append(i.text)
statelist

#getting GSDP[19-20]
gsdp1=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[3]")
for i in gsdp1:
    #print(i.text)
    gsdplist1.append(i.text)
gsdplist1

#getting GSDP[18-19]
gsdp2=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[4]")
for i in gsdp2:
    #print(i.text)
    gsdplist2.append(i.text)
gsdplist2

#getting share
shares=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[5]")
for i in shares:
    #print(i.text)
    sharelist.append(i.text)
sharelist

#getting GDP
gdps=driver.find_elements_by_xpath("//table[@class='display dataTable']/tbody/tr/td[6]")
for i in gdps:
    #print(i.text)
    gdplist.append(i.text)
#gdplist
statistics=pd.DataFrame({})
statistics['Rank']=ranklist
statistics['State']=statelist
statistics['GSDP[19-20]']=gsdplist1
statistics['GSDP[18-19]']=gsdplist2
statistics['Share']=sharelist
statistics['GDP($billion)']=gdplist
statistics
# Out:
# Legality Response number from our URL is: <Response [200]>
# https://statisticstimes.com/economy/india-statistics.php
#    Rank                      State GSDP[19-20] GSDP[18-19]   Share  \
# 0     1                Maharashtra           -   2,632,792  13.94%
# 1     2                 Tamil Nadu   1,845,853   1,630,208   8.63%
# 2     3              Uttar Pradesh   1,687,818   1,584,764   8.39%
# 3     4                    Gujarat           -   1,502,899   7.96%
# 4     5                  Karnataka   1,631,977   1,493,127   7.91%
# ..  ...                        ...         ...         ...     ...
# 61   29                     Sikkim      28,391      25,141   0.15%
# 62   30                   Nagaland           -      24,534   0.15%
# 63   31          Arunachal Pradesh           -      22,488   0.13%
# 64   32                    Mizoram      24,424      20,947   0.13%
# 65   33  Andaman & Nicobar Islands           -           -       -
#
#    GDP($billion)
# 0        399.921
# ...

# %%
url = "https://github.com/trending"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
driver.get(url)
driver.maximize_window()
# making empty lists    
repo_urls=[]
Contributors_count=[]
Language_used=[]
repo_title=[]
repo_desc=[]

#scraping repositories urls
repos=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']/a")
for i in repos:
    repo_urls.append(i.get_attribute('href'))


    
#scraping repositories title
repo_title=[]
try:
    repos=driver.find_elements_by_xpath("//h1[@class='h3 lh-condensed']")
    for i in repos:
        repo_title.append(i.text)
except NoSuchElementException:#handling no such element exception
    repo_title.append('No details available')

    

for i in repo_urls:
    driver.get(i)
    l=[]
    
    #scraping repositories discription
    try:
        repo = driver.find_element_by_xpath("/html/body/div[4]/div/main/div[2]/div/div/div[2]/div[2]/div/div[1]/div/p")
        repo_desc.append(repo.text)
    except NoSuchElementException:
        repo_desc.append('-')
    
    #scraping contributors count
    try:
        count=driver.find_element_by_xpath("//h2[@class='h4 mb-3']/a[contains(text(),'Contributors')]/span")
        Contributors_count.append(count.text)
    except NoSuchElementException:#handling no such element exception
        Contributors_count.append('No details available')
    
    
     #scraping languages used   
    languages=driver.find_elements_by_xpath("//li[@class='d-inline']//a//span[1]")
    if languages:    
        for i in languages:
            l.append(i.text)
    else:
        l.append('No languages used')
    Language_used.append(l)   
    
   
#creating dataframe
df=pd.DataFrame({'Title':repo_title,
                'Description':repo_desc,
                'Contributors_count':Contributors_count,
                'Language_used':Language_used})
df
# Out:
# Legality Response number from our URL is: <Response [200]>
#                                                 Title  \
# 0                                v4d1 / SpoofThatMail
# 1                                 windowjs / windowjs
# 2                                   withastro / astro
# 3                                  CyC2018 / CS-Notes
# 4                                   apache / superset
# 5                              eugeneyan / applied-ml
# 6                           cyrildiagne / ar-cutpaste
# 7                               abigsoft / jdog202201
# 8                              sottlmarek / DevSecOps
# 9                         facebookresearch / ConvNeXt
# 10                      input-output-hk / plutus-apps
# 11                            crater-invoice / crater
# 12          MoienTajik / AspNetCore-Developer-Roadmap
# 13         windowtoolbox / powershell-windows-toolbox
# 14  commit-live-students / Data_Science_Masters_Pr...
# ...

# %%
driver=webdriver.Chrome('chromedriver.exe')
driver.get('https://www.billboard.com/')
driver.maximize_window()

#getting the billboard 200 page
billboard_200=driver.find_element_by_xpath("//a[@class='c-link  lrv-a-unstyle-link lrv-u-whitespace-nowrap lrv-u-text-align-center lrv-u-display-table u-letter-spacing-0080 u-align-items-baseline lrv-u-color-grey-dark a-font-primary-bold u-font-size-11 lrv-u-color-black a-icon-magazine lrv-a-icon-after a-icon-after-11 lrv-u-padding-tb-050 lrv-u-padding-lr-1 lrv-u-text-transform-uppercase u-min-width-40p@desktop-max lrv-u-margin-lr-auto']")
driver.get(billboard_200.get_attribute('href'))

#creating the empty list
song=[]
name=[]
lweek=[]
peak=[]
week=[]
songlist=[]
#scraping for song name
for i in driver.find_elements_by_xpath("//h3[@id='title-of-a-story']"):
    song.append(i.text)
songlist=song[4::2]
print(songlist)
#scraping for name of the artist
x=driver.find_elements_by_xpath("//span[@class='c-label  a-no-trucate a-font-primary-s lrv-u-font-size-14@mobile-max u-line-height-normal@mobile-max u-letter-spacing-0021 lrv-u-display-block a-truncate-ellipsis-2line u-max-width-330 u-max-width-230@tablet-only u-font-size-20@tablet']").text

for i in driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // lrv-u-flex-grow-1 lrv-u-flex lrv-u-flex-direction-column lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-padding-l-050 lrv-u-padding-l-1@mobile-max']/span[1]"):
    name.append(i.text)
name[:0]=[x]
print(name)
#scraping for last week rank 
for i in driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1']/span[1]"):
    lweek.append(i.text)
print(lweek)
#scraping for peak rank
for i in driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-bg-color a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-background-color-grey-lightest lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light lrv-u-flex-grow-1']/span[1]"):
    peak.append(i.text)
print(peak)
#scraping for Weeks on board
for i in driver.find_elements_by_xpath("//li[@class='o-chart-results-list__item // a-chart-color u-width-72 u-width-55@mobile-max u-width-55@tablet-only lrv-u-flex lrv-u-flex-shrink-0 lrv-u-align-items-center lrv-u-justify-content-center lrv-u-border-b-1 u-border-b-0@mobile-max lrv-u-border-color-grey-light u-background-color-white-064@mobile-max lrv-u-flex-grow-1']/span[1]"):
    week.append(i.text)
print(week)
#creating the dataframe
print(len(songlist),len(name),len(lweek),len(peak),len(week))
'''Billboard100={'Song Name':song,'Artist Name':name,'Last Week Rank':lweek,'Peak Rank':peak,'Weeks on board':week}
Billboard100=pd.DataFrame(data=Billboard100)
Billboard100[:100]'''
# Out:
# ['Encanto', '30', 'Dangerous: The Double Album', 'Sour', "Red (Taylor's Version)", 'Certified Lover Boy', 'Planet Her', 'The Highlights', 'Fighting Demons', 'Hall Of Fame', '=', 'Still Over It', 'F*ck Love', 'Happier Than Ever', 'Rumours', 'Montero', 'Live Life Fast', 'Future Nostalgia', 'My Turn', 'Shoot For The Stars Aim For The Moon', "Hollywood's Bleeding", 'An Evening With Silk Sonic', 'Goodbye & Good Riddance', 'What You See Is What You Get', 'SoulFly', 'Donda', 'From The Bayou', 'Justice', 'Legends Never Die', 'good kid, m.A.A.d city', "A Gangsta's Pain", 'Folklore', 'Sincerely, Kentrell', 'Fine Line', 'Evermore', 'Who Is Nardo Wick?', 'Greatest Hits', 'Sniper Gang Presents Syko Bob & SnapKatt: Nightmare Babies', 'Anniversary Trilogy', 'Whole Lotta Red', "This One's For You", 'Curtain Call: The Hits', 'If I Know Me', 'Diamonds', 'When We All Fall Asleep, Where Do We Go?', 'Dreamland', 'Hamilton: An American Musical', 'The Voice Of The Heroes', 'Starting Over', 'Traveller', 'Ct
# ...

# %%
driver=webdriver.Chrome(r"chromedriver.exe")
 
driver.get("https://www.naukri.com/recruiters")
#getting recuriter link

search=driver.find_element_by_xpath("//div[@class='inpWrap']/input")
search.send_keys("Data science")
search=driver.find_element_by_xpath("//button[@class='fl qsbSrch blueBtn']")
search.click()

name = []
designation = []
company = []
skills = []
location = []

# fetching Names
for i in driver.find_elements_by_xpath("//span[@class='fl ellipsis']"):
    name.append(i.text)
    
# fetching Designation
for i in driver.find_elements_by_xpath("//span[@class='ellipsis clr']"):
    designation.append(i.text)

# fetching Company names
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]/a[2]"):
    company.append(i.text)
    
# fetching  Skills
for i in driver.find_elements_by_xpath("//div[@class='hireSec highlightable']"):
    try:
        if i.text == "Not Specified": raise NoSuchElementException
        skills.append(i.text)
    except NoSuchElementException:
        skills.append('-')
                
# fetching Locations
for i in driver.find_elements_by_xpath("//div[@class='vcard']//p[1]//span"):
    location.append(i.text)
    
# Creating a dataframe
data = list(zip(name, designation, company, skills, location))
df = pd.DataFrame(data, columns = ["Name", "Designation", "Company Name", "Skills they hire for", "Location"])
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            shravan Kumar Gaddam
# 2                        MARSIAN Technologies LLP
# 3                                    Anik Agrawal
# 4                                    subhas patel
# 5    Abhishek - Only Analytics Hiring - India and
# 6   Institute for Financial Management and Resear
# 7                                     Balu Ramesh
# 8                                   Asif Lucknowi
# 9                                 InstaFinancials
# 10                                 Priyanka Akiri
# 11                                Kalpana Dumpala
# 12                                        Mubarak
# 13                                 Kushal Rastogi
# 14                             Mahesh Babu Channa
# 15                                Sakshi Chhikara
# 16                                   Kapil Devang
# 17                                    Ruchi Dhote
# ...

# %%
url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare/"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
driver.maximize_window()

Book_name = []
Author_name = []
Volume_sold = []
Publisher = []
Genre = []

try: # Scraping Book name
    for i in driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[2]"):
        Book_name.append(i.text)
except NoSuchElementException as e:
    print("-")
    
try: # Scraping Author name
    for i in driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[3]"):
        Author_name.append(i.text)
except NoSuchElementException as e:
    print("-")
        
try: # Scraping Volume sold
    for i in driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[4]"):
        Volume_sold.append(i.text)
except NoSuchElementException as e:
    print("-")
    
try: # Scraping Publisher
    for i in driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[5]"):
        Publisher.append(i.text)
except NoSuchElementException as e:
    print("-") 
    
try: # Scraping Genre
    for i in driver.find_elements_by_xpath("//div[@class='embed block']/table/tbody/tr/td[6]"):
        Genre.append(i.text)
except NoSuchElementException as e:
    print("-")
    
# Creating data frame 
Books=pd.DataFrame({'Book Name': Book_name, 'Author Name': Author_name, 'Volume Sold': Volume_sold,
                    'Publisher': Publisher, 'Genre' : Genre})
Books
# Out:
# Legality Response number from our URL is: <Response [200]>
#                                             Book Name       Author Name  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# 96                     Happy Days with the Naked Chef     Oliver, Jamie
# 97              Hunger Games,The:Hunger Games Trilogy  Collins, Suzanne
# 98  Lost Boy,The:A Foster Child's Search for the L...      Pelzer, Dave
# 99  Jamie's Ministry of Food:Anyone Can Learn to C...     Oliver, Jamie
#
# ...

# %%
url = "https://www.imdb.com/list/ls095964455/"
page = requests.get(url)
print("Legality Response number from our URL is:", page) # to show the response output from the webpage
soup = BeautifulSoup(page.content)

driver = webdriver.Chrome('chromedriver.exe')
driver.get(url)
driver.maximize_window()

name = []
year = []
genre = []
runtime = []
rating = []
vote = []

try: # Scraping Name
    for i in driver.find_elements_by_xpath("//h3[@class='lister-item-header']/a"):
        name.append(i.text)
except NoSuchElementException as e:
    print("-")
    
try: # Scraping Year span
    for i in driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']"):
        year.append(i.text)
except NoSuchElementException as e:
    print("-")
        
try: # Scraping Genre
    for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']/p/span[5]"):
        genre.append(i.text)
except NoSuchElementException as e:
    print("-")
    
try: # Scraping Run time
    for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']/p/span[3]"):
        runtime.append(i.text)
except NoSuchElementException as e:
    print("-") 
    
try: # Scraping Ratings
    for i in driver.find_elements_by_xpath("//div[@class='ipl-rating-star small']/span[2]"):
        rating.append(i.text)
except NoSuchElementException as e:
    print("-")
    
try: # Scraping votes
    for i in driver.find_elements_by_xpath("//div[@class='lister-item-content']/p[4]/span[2]"):
        vote.append(i.text)
except NoSuchElementException as e:
    print("-")

# Creating a dataframe 
imdb=pd.DataFrame({'Name':name, 'Year Span':year, 'Genre':genre, 'Run Time':runtime, 'Ratings':rating, 'Votes':vote})
imdb
# Out:
# Legality Response number from our URL is: <Response [200]>
#                               Name    Year Span                     Genre  \
# 0                  Game of Thrones  (2011–2019)  Action, Adventure, Drama
# 1                  Stranger Things     (2016– )    Drama, Fantasy, Horror
# 2                 The Walking Dead  (2010–2022)   Drama, Horror, Thriller
# 3                   13 Reasons Why  (2017–2020)  Drama, Mystery, Thriller
# 4                          The 100  (2014–2020)    Drama, Mystery, Sci-Fi
# ..                             ...          ...                       ...
# 95                           Reign  (2013–2017)            Drama, Fantasy
# 96  A Series of Unfortunate Events  (2017–2019)  Adventure, Comedy, Drama
# 97                  Criminal Minds  (2005–2020)     Crime, Drama, Mystery
# 98           Scream: The TV Series  (2015–2019)      Comedy, Crime, Drama
# 99      The Haunting of Hill House       (2018)    Drama, Horror, Mystery
#
# ...

# %%
# Activating the chrome browser
driver=webdriver.Chrome("chromedriver.exe") 
time.sleep(2)

# Opening the imdb.com
url = "https://archive.ics.uci.edu/"
driver.get(url)
time.sleep(2)

#clicking show all datasets link
show=driver.find_element_by_xpath("//a[@href='datasets.php']")
show.click()
time.sleep(1)


#scraping dataset names
name=[]
try:
    names=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[1]/table/tbody/tr/td[2]/p/b/a")
    for i in names:
        name.append(i.text)
except NoSuchElementException:#handling no such element exception
    name.append('No details available')
time.sleep(2)

#scraping data type
data_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[2]")
    for i in info[1:]:
         data_type.append(i.text)
except NoSuchElementException:
    data_type.append("No information")
time.sleep(2)


#scraping dataset names
default_task=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[3]")
    for i in info[1:]:
         default_task.append(i.text)
except NoSuchElementException:
    default_task.append("No information")
time.sleep(2)


#scraping dataset names
attr_type=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[4]")
    for i in info[1:]:
         attr_type.append(i.text)
except NoSuchElementException:
    attr_type.append("No information")
time.sleep(2)


#scraping dataset names
no_of_instances=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[5]")
    for i in info[1:]:
         no_of_instances.append(i.text)
except NoSuchElementException:
    no_of_instances.append("No information")
time.sleep(2)


#scraping dataset names
no_of_attributes=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[6]")
    for i in info[1:]:
         no_of_attributes.append(i.text)
except NoSuchElementException:
    no_of_attributes.append("No information")
time.sleep(2)


#scraping dataset names
year=[]
try:
    info=driver.find_elements_by_xpath("/html/body/table[2]/tbody/tr/td[2]/table[2]/tbody/tr/td[7]")
    for i in info[1:]:
         year.append(i.text)
except NoSuchElementException:
    year.append("No information")
time.sleep(2)

#creating dataframe
df=pd.DataFrame({'Name':name,
                'Data_type':data_type,
                'Task':default_task,
                'Attribute_type':attr_type,
                'No_of_instances':no_of_instances,
                'No_of_attributes':no_of_attributes,
                'Year':year})
df
# Out:
#                                                   Name  \
# 0                                              Abalone
# 1                                                Adult
# 2                                            Annealing
# 3                         Anonymous Microsoft Web Data
# 4                                           Arrhythmia
# ..                                                 ...
# 617  Influenza outbreak event prediction via Twitte...
# 618                      Turkish Music Emotion Dataset
# 619                      Maternal Health Risk Data Set
# 620                          Room Occupancy Estimation
# 621  Image Recognition Task Execution Times in Mobi...
#
#                       Data_type                  Task  \
# 0                 Multivariate        Classification
# 1                 Multivariate        Classification
# 2                 Multivariate        Classification
# 3                                Recommender-Systems
# ...
