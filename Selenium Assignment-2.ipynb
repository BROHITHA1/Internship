# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import StaleElementReferenceException
from selenium.common.exceptions import ElementClickInterceptedException

# %%
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# Out:
# <ipython-input-2-66d5abec237a>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")

# %%
driver.get('https://www.amazon.in')

# obtaining the search option on our web driver
search = driver.find_element_by_id('twotabsearchtextbox')

# obtaining the item to be searched from the user
search = driver.find_element_by_id("twotabsearchtextbox")
item = str(input("Item name that you want to search for : "))
search.send_keys(item)

# performing a click using xpath function in our web driver
search_btn = driver.find_element_by_xpath("//span[@class='nav-search-submit-text nav-sprite nav-progressive-attribute']")
search_btn.click()
# Out:
# <ipython-input-3-446817ee9b0d>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id('twotabsearchtextbox')
# <ipython-input-3-446817ee9b0d>:7: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search = driver.find_element_by_id("twotabsearchtextbox")
# Item name that you want to search for : Sound bars
# <ipython-input-3-446817ee9b0d>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath("//span[@class='nav-search-submit-text nav-sprite nav-progressive-attribute']")

# %%
url_list=[]
urls=driver.find_element_by_xpath("//li[@class='a-selected']/a")
url=urls.get_attribute("href")
url_list.append(url)
url_list
# Out:
# <ipython-input-4-30a192d021ba>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   urls=driver.find_element_by_xpath("//li[@class='a-selected']/a")
# ['https://www.amazon.in/s?k=Sound+bars&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_1']

# %%
urls=driver.find_elements_by_xpath("//li[@class='a-normal']/a")
for i in urls:
    url=i.get_attribute("href")
    url_list.append(url)
url_list
# Out:
# <ipython-input-5-6de9f7d3fc4b>:1: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   urls=driver.find_elements_by_xpath("//li[@class='a-normal']/a")
# ['https://www.amazon.in/s?k=Sound+bars&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_1',
#  'https://www.amazon.in/s?k=Sound+bars&page=2&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_2',
#  'https://www.amazon.in/s?k=Sound+bars&page=3&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_3']

# %%
from selenium.common.exceptions import StaleElementReferenceException        


try:
    for i in range(0,len(url_list)):
        print("NEXT PAGE")
        print(url_list[i])
        driver.get(url_list[i])

except StaleElementReferenceException as e:
    print("Exception:::",e)
# Out:
# NEXT PAGE
# https://www.amazon.in/s?k=Sound+bars&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_1
# NEXT PAGE
# https://www.amazon.in/s?k=Sound+bars&page=2&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_2
# NEXT PAGE
# https://www.amazon.in/s?k=Sound+bars&page=3&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_3

# %%
#Getting product urls and Titles.
from selenium.common.exceptions import StaleElementReferenceException    
productUrlList=[]
ProductTitle_List=[]
try:
    for i in range(0,len(url_list)):
        print(url_list[i])
        driver.get(url_list[i])#Pages Link

        product_url=driver.find_elements_by_xpath("//a[@class='a-link-normal s-link-style a-text-normal']")#each watch URL
        for i in product_url:
            time.sleep(2)
            p_url=i.get_attribute("href")#getting the Urls of each watches
            ProductTitle_List.append(i.text)#getting title of each watch.
            productUrlList.append(p_url)

   
            
except StaleElementReferenceException as e:
        print("EXCEPTION:::",e)
print(len(ProductTitle_List))
print(len(productUrlList))
# Out:
# https://www.amazon.in/s?k=Sound+bars&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_1
# <ipython-input-7-a1b2fa5f0a72>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   product_url=driver.find_elements_by_xpath("//a[@class='a-link-normal s-link-style a-text-normal']")#each watch URL
# https://www.amazon.in/s?k=Sound+bars&page=2&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_2
# https://www.amazon.in/s?k=Sound+bars&page=3&crid=2EBJ2H6Q3ZB70&qid=1641058760&sprefix=%2Caps%2C258&ref=sr_pg_3
# 66
# 66

# %%
from selenium.common.exceptions import NoSuchElementException
brand=[]
prod_name=[]
rating=[]
rating_num=[]
price= []
ret_ex=[]
exp_del = []
availability=[]
prod_url=[]
ot_det = []

# obtaining all the details one after another
for i in productUrlList[:150]:
    driver.get(i)
    time.sleep(3)
    
    # getting the brand name
    try:
        brand_name=driver.find_element_by_xpath("//td[@class='a-span9']/span")
        brand.append(brand_name.text)
    except NoSuchElementException:
        brand.append('-')    
                
      # getting the product name
    try:
        product=driver.find_element_by_id("productTitle")
        prod_name.append(product.text)
    except NoSuchElementException:
        prod_name.append('-')         
        
      # getting the rating
    try:
        ratestar=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
        rating.append(ratestar.text)
    except NoSuchElementException:
        rating.append("No Rating")       
                
      # getting the rating number
    try:
        ratenum=driver.find_element_by_id("acrCustomerReviewText")
        rating_num.append(ratenum.text)
    except NoSuchElementException:
        rating_num.append('-')         
                
      # getting the price
    try:
        prod_price=driver.find_element_by_id("priceblock_ourprice")
        price.append(prod_price.text)
    except NoSuchElementException:
        price.append('-')      
                
     # getting the return/exchange
    try:
        ret_exch=driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
        ret_ex.append(ret_exch.get_attribute("href"))
    except NoSuchElementException:
        ret_ex.append('-') 
        
     # getting the expected delivery
    try:
        ex_de=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
        exp_del.append(ex_de.text)
    except NoSuchElementException:
        exp_del.append('-')           
               
     # getting the availability
    try:
        availa=driver.find_element_by_id("availability")
        availability.append(availa.text)
    except NoSuchElementException:
        availability.append('-')       
                           
     # getting the product url
    try:
        pro_url=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content']/a")
        prod_url.append(pro_url.get_attribute("href"))
    except NoSuchElementException:
        prod_url.append('-')
        
     # getting the other details
    try:
        othr_det=driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']/li/span")
        ot_det.append(othr_det.text)
    except NoSuchElementException:
        ot_det.append('-')
        
# creating the entire dataframe now
item_df = pd.DataFrame({})
item_df['Brand Name'] = brand
item_df['Product Name'] = prod_name
item_df['Rating'] = rating
item_df['Rating Number'] = rating_num
item_df['Price'] = price
item_df['Return/Exchange'] = ret_ex
item_df['Expected Delivery'] = exp_del
item_df['Availability'] = availability
item_df['Product URLs'] = prod_url
item_df['Other Details'] = ot_det     
item_df
# Out:
# <ipython-input-8-2cb68883beda>:20: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand_name=driver.find_element_by_xpath("//td[@class='a-span9']/span")
# <ipython-input-8-2cb68883beda>:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   product=driver.find_element_by_id("productTitle")
# <ipython-input-8-2cb68883beda>:34: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ratestar=driver.find_element_by_xpath("//span[@class='a-size-base a-nowrap']//span")
# <ipython-input-8-2cb68883beda>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ratenum=driver.find_element_by_id("acrCustomerReviewText")
# <ipython-input-8-2cb68883beda>:48: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prod_price=driver.find_element_by_id("priceblock_ourprice")
# <ipython-input-8-2cb68883beda>:55: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ret_exch=driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
# <ipython-input-8-2cb68883beda>:62: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ex_de=driver.find_element_by_xpath("//div[@class='a-section a-spacing-mini']/b")
# <ipython-input-8-2cb68883beda>:69: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   availa=driver.find_element_by_id("availability")
# <ipython-input-8-2cb68883beda>:76: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pro_url=driver.find_element_by_xpath("//div[@class='a-section a-spacing-none icon-content']/a")
# <ipython-input-8-2cb68883beda>:83: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   othr_det=driver.find_element_by_xpath("//ul[@class='a-unordered-list a-vertical a-spacing-mini']/li/span")
#                                    Brand Name  \
# 0   Wireless, Bluetooth, Auxiliary, USB, HDMI
# 1                   Bluetooth, Auxiliary, USB
# 2         Wireless, Bluetooth, Auxiliary, USB
# 3                          Wireless Bluetooth
# 4   Wireless, Bluetooth, Auxiliary, USB, HDMI
# ..                                        ...
# 61            Bluetooth, Auxiliary, USB, HDMI
# 62  Wireless, Bluetooth, Auxiliary, USB, HDMI
# 63  Wireless, Bluetooth, Auxiliary, USB, HDMI
# 64                        Wireless, Bluetooth
# 65                         Wireless Bluetooth
#
#                                          Product Name        Rating  \
# 0   boAt AAVANTE Bar 1190 90W 2.2 Channel Bluetoot...  4.2 out of 5
# 1   boAt Aavante Bar 1250 80 Watt 2.1 Channel Wire...  4.3 out of 5
# 2   boAt Aavante Bar 1160 60 Watt 2.0 Channel Wire...  4.1 out of 5
# 3   Infinity (JBL) Sonic B200WL, 160W Soundbar wit...  3.9 out of 5
# 4   boAt AAVANTE Bar 1190 90W 2.2 Channel Bluetoot...  4.2 out of 5
# ..                                                ...           ...
# 61  Zebronics Zeb-Juke BAR 3850 PRO Dolby Atmos so...  4.1 out of 5
# 62  Artis BT-X5 60 Watts 2.0 Channel Wireless Blue...  3.7 out of 5
# 63  (Renewed) boAt AAVANTE Bar 1300 60 Watt 2.0 Ch...    3 out of 5
# 64  (Renewed) Boat Aavante Bar 2050 160W 2.1 Chann...  3.3 out of 5
# 65  Zebronics Zeb-JUKEBAR 9000 PRO Dolby, 120W Mul...  4.1 out of 5
#
#      Rating Number Price                                    Return/Exchange  \
# 0    5,059 ratings     -  https://www.amazon.in/Bluetooth-Soundbar-Subwo...
# 1    3,275 ratings     -  https://www.amazon.in/Bluetooth-Signature-Subw...
# 2   11,640 ratings     -  https://www.amazon.in/Boat-1160-Bluetooth-Comp...
# 3    2,698 ratings     -  https://www.amazon.in/Infinity-B200WL-Channel-...
# 4    5,059 ratings     -  https://www.amazon.in/Bluetooth-Soundbar-Subwo...
# ..             ...   ...                                                ...
# 61   3,562 ratings     -  https://www.amazon.in/Zebronics-Zeb-Juke-sound...
# 62     432 ratings     -  https://www.amazon.in/Artis-Wireless-Bluetooth...
# 63       3 ratings     -  https://www.amazon.in/boAt-Bar-Wireless-Blueto...
# 64     101 ratings     -  https://www.amazon.in/Bluetooth-Signature-Subw...
# 65   3,562 ratings     -  https://www.amazon.in/Zebronics-Zeb-JUKEBAR-90...
#
#    Expected Delivery Availability  \
# 0   Wednesday, Jan 5    In stock.
# 1    Thursday, Jan 6    In stock.
# 2    Thursday, Jan 6    In stock.
# 3      Friday, Jan 7
# 4   Wednesday, Jan 5    In stock.
# ..               ...          ...
# 61     Friday, Jan 7    In stock.
# 62     Friday, Jan 7    In stock.
# 63   Thursday, Jan 6    In stock.
# 64     Friday, Jan 7    In stock.
# 65  Wednesday, Jan 5    In stock.
#
#                                          Product URLs  \
# 0   https://www.amazon.in/Bluetooth-Soundbar-Subwo...
# 1   https://www.amazon.in/Bluetooth-Signature-Subw...
# 2   https://www.amazon.in/Boat-1160-Bluetooth-Comp...
# 3   https://www.amazon.in/Infinity-B200WL-Channel-...
# 4   https://www.amazon.in/Bluetooth-Soundbar-Subwo...
# ..                                                ...
# 61  https://www.amazon.in/Zebronics-Zeb-Juke-sound...
# 62  https://www.amazon.in/Artis-Wireless-Bluetooth...
# 63  https://www.amazon.in/boAt-Bar-Wireless-Blueto...
# 64  https://www.amazon.in/Bluetooth-Signature-Subw...
# 65  https://www.amazon.in/Zebronics-Zeb-JUKEBAR-90...
#
#                                         Other Details
# 0   Its 2.2 Channel captivating sound gets you set...
# 1   Its 2.1 Channel captivating sound gets you set...
# 2   Control your playback via easy operational con...
# 3   160W Peak Power Output Powerful Soundbar with ...
# 4   Its 2.2 Channel captivating sound gets you set...
# ..                                                ...
# 61  Soundbar with 2.0.2 configuration, supporting ...
# 62  The Artis X5 SoundBar raises the bar of giving...
# 63  This Renewed product is tested to work and loo...
# 64  This Certified Refurbished product is tested t...
# 65                      BT/USB/AUX/HDMI(ARC) /OPTICAL
#
# [66 rows x 10 columns]

# %%
# exporting the above dataframe in csv format
item_df.to_csv(r"C:\Users\DELL\DS Task\item_details_from_amazon.csv", index=False)

# %%
# obtaining the web page details with the given url
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
url='https://images.google.com/'
urls = []    # empty list for image urls to download
data = []    # empty list for storing data
search_item = ["Fruits", "Cars", "Machine Lear

driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
url = "https://www.flipkart.com/"
driver.get(url)
time.sleep(3)  # waiting for 3 seconds here
click_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()
#giving inputs to search bar
search_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
search_bar.send_keys("Smartphones")
search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
search_btn.click()
time.sleep(5)
# Out:
# <ipython-input-18-42a3ee9470f2>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# <ipython-input-18-42a3ee9470f2>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   click_btn = driver.find_element_by_xpath("//div[@class='_2QfC02']//button").click()
# <ipython-input-18-42a3ee9470f2>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_bar = driver.find_element_by_xpath("//div[@class='_3OO5Xc']//input")
# <ipython-input-18-42a3ee9470f2>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# %%
# fetching urls of every smartphone on Flipkart
urls = []
for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
    urls.append(i.get_attribute("href"))

# getting the required data inside the empty lists
brand_names = []
name = []
color = []
RAM = []
storage = []
prim_cam = []
sec_cam = []
Display_size = []
display_resolution = []
processor = []
processor_core = []
battery_cap = []
prices = []
product_url = []

# fetching battery capacity
for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
    try:
        bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
        battery_cap.append(bat_cap.text)
    except NoSuchElementException:
        battery_cap.append('-')
for i in urls:
    driver.get(i)
    time.sleep(3)
    
    # fetching brand names
    try:
        br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
        brand_names.append(br_name.text.replace('Mobiles',''))
    except NoSuchElementException:
        brand_names.append('-')
    # fetching the smartphone names
    try:
        smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
        name.append(smt_name.text)
    except NoSuchElementException:
        name.append('-')
    
    # fetching colors of smartphone
    try:
        clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
        color.append(clr.text)
    except NoSuchElementException:
        color.append('-')
    time.sleep(2)
    
    # getting the read more button
    try:
        read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
    except NoSuchElementException:
        pass
    time.sleep(3)
    
    # fetching the display size
    try:
        disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
        Display_size.append(disp_size.text)
    except NoSuchElementException:
        Display_size.append
        
    # fetching the display resolution
    try:
        disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
        display_resolution.append(disp_res.text)
    except NoSuchElementException:
        display_resolution.append('-')
        
    # fetching the processor information
    try:
        pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
        processor.append(pro.text)
    except NoSuchElementException:
        processor.append('-')
        
    # fetching the processor and number of core details
    try:
        pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
        processor_core.append(pro_core.text)
    except NoSuchElementException:
        processor_core.append('-')
        
    # fetching the storage/ROM details
    try:
        rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
        storage.append(rom.text)
    except NoSuchElementException:
        storage.append('-')
        
    # fetching the RAM information
    try:
        ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
        RAM.append(ram.text)
    except NoSuchElementException:
        RAM.append('-')
    time.sleep(2)
    
    # fetching the primary camera information
    try:
        p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
        prim_cam.append(p_cam.text)
    except NoSuchElementException:
        prim_cam.append('-')
        
    # fetching the secondary camera information
    try:
        s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
        sec_cam.append(s_cam.text)
    except NoSuchElementException:
        sec_cam.append('-')        
   
    # fetching the price of the smartphone
    try:
        price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        prices.append(price.text.replace('₹','Rs. '))
    except NoSuchElementException:
        prices.append('-')
    
    
# creating a dataframe now with the obtainined details
data = list(zip(brand_names,name,color,RAM,storage,prim_cam,sec_cam,Display_size,display_resolution,processor,
                processor_core,battery_cap,prices,urls))
phone_df = pd.DataFrame(data, columns = ["Brand Name","Smartphone Name","Color","RAM","Storage/ROM","Primary Camera",
                                   "Secondary Camera","Display Size","Display Resolution","Processor","Processor-Core",
                                   "Battery Capacity","Price","Product Url"])
phone_df
# Out:
# <ipython-input-19-cacaa71ebf5c>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//a[@class='_1fQZEK']"):
# <ipython-input-19-cacaa71ebf5c>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='fMghEO']"):
# <ipython-input-19-cacaa71ebf5c>:25: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bat_cap = driver.find_element_by_xpath("//ul[@class='_1xgFaf']//li[4]")
# <ipython-input-19-cacaa71ebf5c>:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   br_name = driver.find_element_by_xpath("/html/body/div/div/div[3]/div[1]/div[2]/div[1]/div[1]/div/div[4]/a")
# <ipython-input-19-cacaa71ebf5c>:41: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   smt_name = driver.find_element_by_xpath("//h1[@class='yhB1nd']//span")
# <ipython-input-19-cacaa71ebf5c>:48: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   clr = driver.find_element_by_xpath("//table[@class='_14cfVK']//tr[4]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:56: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   read_more_btn = driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']").click()
# <ipython-input-19-cacaa71ebf5c>:63: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_size = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[1]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:70: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_res = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[2]//tr[2]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:77: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pro = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[2]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:84: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pro_core = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[3]//tr[3]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:91: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rom = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[1]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:98: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   ram = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[4]//tr[2]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:106: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   p_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[2]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:113: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   s_cam = driver.find_element_by_xpath("//div[@class='_1UhVsV']//div[5]//tr[5]//td[2]")
# <ipython-input-19-cacaa71ebf5c>:120: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price = driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
#    Brand Name                                    Smartphone Name  \
# 0      APPLE                 APPLE iPhone 12 Mini (Black, 64 GB)
# 1     realme   realme Narzo 50A (Oxygen Blue, 64 GB)  (4 GB RAM)
# 2     realme       realme C25_Y (Metal Grey, 128 GB)  (4 GB RAM)
# 3     realme      realme C25Y (Glacier Blue, 128 GB)  (4 GB RAM)
# 4     realme        realme C25Y (Metal Grey, 128 GB)  (4 GB RAM)
# 5     realme       realme C25Y (Glacier Blue, 64 GB)  (4 GB RAM)
# 6     realme         realme C25Y (Metal Grey, 64 GB)  (4 GB RAM)
# 7     realme   realme Narzo 50A (Oxygen Green, 64 GB)  (4 GB ...
# 8     realme   realme Narzo 50A (Oxygen Green, 128 GB)  (4 GB...
# 9     realme   realme Narzo 50A (Oxygen Blue, 128 GB)  (4 GB ...
# 10     REDMI        REDMI 9i (Midnight Black, 64 GB)  (4 GB RAM)
# 11     REDMI     REDMI 9i Sport (Coral Green, 64 GB)  (4 GB RAM)
# 12     REDMI          REDMI 9i (Nature Green, 64 GB)  (4 GB RAM)
# 13     APPLE                      APPLE iPhone 12 (Black, 64 GB)
# 14    realme     realme C25_Y (Glacier Blue, 128 GB)  (4 GB RAM)
# 15     REDMI              REDMI 9i (Sea Blue, 64 GB)  (4 GB RAM)
# 16    realme      realme C11 2021 (Cool Grey, 32 GB)  (2 GB RAM)
# 17    realme   realme 8s 5G (Universe Purple, 128 GB)  (8 GB ...
# 18    realme      realme C11 2021 (Cool Blue, 64 GB)  (4 GB RAM)
# 19    realme      realme C11 2021 (Cool Grey, 64 GB)  (4 GB RAM)
# 20    realme      realme C11 2021 (Cool Blue, 32 GB)  (2 GB RAM)
# 21     APPLE                      APPLE iPhone SE (Black, 64 GB)
# 22      POCO            POCO C31 (Royal Blue, 64 GB)  (4 GB RAM)
# 23     APPLE                  APPLE iPhone 12 Mini (Blue, 64 GB)
#
#               Color                                         RAM Storage/ROM  \
# 0             Black                                           -       64 GB
# 1       Oxygen Blue                                        4 GB       64 GB
# 2        Metal Grey                                        4 GB      128 GB
# 3      Glacier Blue                                        4 GB      128 GB
# 4        Metal Grey                                        4 GB      128 GB
# 5      Glacier Blue                                        4 GB       64 GB
# 6        Metal Grey                                        4 GB       64 GB
# 7      Oxygen Green                                        4 GB       64 GB
# 8      Oxygen Green                                        4 GB      128 GB
# 9       Oxygen Blue                                        4 GB      128 GB
# 10   Midnight Black                                        4 GB       64 GB
# 11      Coral Green                                        4 GB       64 GB
# 12     Nature Green                                        4 GB       64 GB
# 13            Black                                           -       64 GB
# 14     Glacier Blue                                        4 GB      128 GB
# 15         Sea Blue                                        4 GB       64 GB
# 16        Cool Grey                                        2 GB       32 GB
# 17  Universe Purple                                        8 GB      128 GB
# 18        Cool Blue                                        4 GB       64 GB
# 19        Cool Grey                                        4 GB       64 GB
# 20        Cool Blue                                        2 GB       32 GB
# 21            Black  A13 Bionic Chip with 3rd Gen Neural Engine    iOS 14.2
# 22       Royal Blue                                        4 GB       64 GB
# 23             Blue                                           -       64 GB
#
#       Primary Camera   Secondary Camera  \
# 0        12MP + 12MP  12MP Front Camera
# 1   50MP + 2MP + 2MP   8MP Front Camera
# 2   50MP + 2MP + 2MP   8MP Front Camera
# 3   50MP + 2MP + 2MP   8MP Front Camera
# 4   50MP + 2MP + 2MP   8MP Front Camera
# 5   50MP + 2MP + 2MP   8MP Front Camera
# 6   50MP + 2MP + 2MP   8MP Front Camera
# 7   50MP + 2MP + 2MP   8MP Front Camera
# 8   50MP + 2MP + 2MP   8MP Front Camera
# 9   50MP + 2MP + 2MP   8MP Front Camera
# 10  13MP Rear Camera   5MP Front Camera
# 11  13MP Rear Camera   5MP Front Camera
# 12  13MP Rear Camera   5MP Front Camera
# 13       12MP + 12MP  12MP Front Camera
# 14  50MP + 2MP + 2MP   8MP Front Camera
# 15  13MP Rear Camera   5MP Front Camera
# 16   8MP Rear Camera   5MP Front Camera
# 17  64MP + 2MP + 2MP  16MP Front Camera
# 18   8MP Rear Camera   5MP Front Camera
# 19   8MP Rear Camera   5MP Front Camera
# 20   8MP Rear Camera   5MP Front Camera
# 21                 -                  -
# 22  13MP + 2MP + 2MP   5MP Front Camera
# 23       12MP + 12MP  12MP Front Camera
#
#                                        Display Size  Display Resolution  \
# 0                               13.72 cm (5.4 inch)  2340 x 1080 Pixels
# 1                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 2                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 3                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 4                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 5                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 6                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 7                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 8                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 9                               16.51 cm (6.5 inch)   1600 x 720 Pixels
# 10                             16.59 cm (6.53 inch)   1600 x 720 Pixels
# 11                             16.59 cm (6.53 inch)   1600 x 720 Pixels
# 12                             16.59 cm (6.53 inch)   1600 x 720 Pixels
# 13                              15.49 cm (6.1 inch)  2532 x 1170 Pixels
# 14                              16.51 cm (6.5 inch)   1600 x 720 Pixels
# 15                             16.59 cm (6.53 inch)   1600 x 720 Pixels
# 16                              16.51 cm (6.5 inch)   1600 x 720 Pixels
# 17                              16.51 cm (6.5 inch)  2400 x 1080 Pixels
# 18                              16.51 cm (6.5 inch)   1600 x 720 Pixels
# 19                              16.51 cm (6.5 inch)   1600 x 720 Pixels
# 20                              16.51 cm (6.5 inch)   1600 x 720 Pixels
# 21  iPhone, USB-C to Lightning Cable, Documentation           MHGP3HN/A
# 22                             16.59 cm (6.53 inch)   1600 x 720 Pixels
# 23                              13.72 cm (5.4 inch)  2340 x 1080 Pixels
#
#                                             Processor     Processor-Core  \
# 0   A14 Bionic Chip with Next Generation Neural En...                  -
# 1                                  MediaTek Helio G85          Octa Core
# 2                                         Unisoc T618          Octa Core
# 3                               Unisoc T610 Octa Core          Octa Core
# 4                               Unisoc T610 Octa Core          Octa Core
# 5                               Unisoc T610 Octa Core          Octa Core
# 6                               Unisoc T610 Octa Core          Octa Core
# 7                                  MediaTek Helio G85          Octa Core
# 8                                  MediaTek Helio G85          Octa Core
# 9                                  MediaTek Helio G85          Octa Core
# 10                                 MediaTek Helio G25          Octa Core
# 11                                 MediaTek Helio G25          Octa Core
# 12                                 MediaTek Helio G25          Octa Core
# 13  A14 Bionic Chip with Next Generation Neural En...                  -
# 14                                        Unisoc T618          Octa Core
# 15                                 MediaTek Helio G25          Octa Core
# 16                                          Octa-core          Octa Core
# 17                          MediaTek Dimensity 810 5G          Octa Core
# 18                                          Octa-core          Octa Core
# 19                                          Octa-core          Octa Core
# 20                                          Octa-core          Octa Core
# 21                                  1334 x 750 Pixels  Retina HD Display
# 22                                 MediaTek Helio G35          Octa Core
# 23  A14 Bionic Chip with Next Generation Neural En...                  -
#
#                                      Battery Capacity       Price  \
# 0   A14 Bionic Chip with Next Generation Neural En...  Rs. 49,999
# 1   A14 Bionic Chip with Next Generation Neural En...  Rs. 11,499
# 2   A14 Bionic Chip with Next Generation Neural En...  Rs. 11,999
# 3   A14 Bionic Chip with Next Generation Neural En...  Rs. 11,999
# 4   A14 Bionic Chip with Next Generation Neural En...  Rs. 11,999
# 5   A14 Bionic Chip with Next Generation Neural En...  Rs. 10,999
# 6   A14 Bionic Chip with Next Generation Neural En...  Rs. 10,999
# 7   A14 Bionic Chip with Next Generation Neural En...  Rs. 11,499
# 8   A14 Bionic Chip with Next Generation Neural En...  Rs. 12,499
# 9   A14 Bionic Chip with Next Generation Neural En...  Rs. 12,499
# 10  A14 Bionic Chip with Next Generation Neural En...   Rs. 8,999
# 11  A14 Bionic Chip with Next Generation Neural En...   Rs. 8,999
# 12  A14 Bionic Chip with Next Generation Neural En...   Rs. 8,999
# 13  A14 Bionic Chip with Next Generation Neural En...  Rs. 59,999
# 14  A14 Bionic Chip with Next Generation Neural En...  Rs. 11,999
# 15  A14 Bionic Chip with Next Generation Neural En...   Rs. 8,999
# 16  A14 Bionic Chip with Next Generation Neural En...   Rs. 7,499
# 17  A14 Bionic Chip with Next Generation Neural En...  Rs. 19,999
# 18  A14 Bionic Chip with Next Generation Neural En...   Rs. 8,999
# 19  A14 Bionic Chip with Next Generation Neural En...   Rs. 8,999
# 20  A14 Bionic Chip with Next Generation Neural En...   Rs. 7,499
# 21  A14 Bionic Chip with Next Generation Neural En...  Rs. 30,499
# 22  A14 Bionic Chip with Next Generation Neural En...   Rs. 9,499
# 23  A14 Bionic Chip with Next Generation Neural En...  Rs. 49,999
#
#                                           Product Url
# 0   https://www.flipkart.com/apple-iphone-12-mini-...
# 1   https://www.flipkart.com/realme-narzo-50a-oxyg...
# 2   https://www.flipkart.com/realme-c25-y-metal-gr...
# 3   https://www.flipkart.com/realme-c25y-glacier-b...
# 4   https://www.flipkart.com/realme-c25y-metal-gre...
# 5   https://www.flipkart.com/realme-c25y-glacier-b...
# 6   https://www.flipkart.com/realme-c25y-metal-gre...
# 7   https://www.flipkart.com/realme-narzo-50a-oxyg...
# 8   https://www.flipkart.com/realme-narzo-50a-oxyg...
# 9   https://www.flipkart.com/realme-narzo-50a-oxyg...
# 10  https://www.flipkart.com/redmi-9i-midnight-bla...
# 11  https://www.flipkart.com/redmi-9i-sport-coral-...
# 12  https://www.flipkart.com/redmi-9i-nature-green...
# 13  https://www.flipkart.com/apple-iphone-12-black...
# 14  https://www.flipkart.com/realme-c25-y-glacier-...
# 15  https://www.flipkart.com/redmi-9i-sea-blue-64-...
# 16  https://www.flipkart.com/realme-c11-2021-cool-...
# 17  https://www.flipkart.com/realme-8s-5g-universe...
# 18  https://www.flipkart.com/realme-c11-2021-cool-...
# 19  https://www.flipkart.com/realme-c11-2021-cool-...
# 20  https://www.flipkart.com/realme-c11-2021-cool-...
# 21  https://www.flipkart.com/apple-iphone-se-black...
# 22  https://www.flipkart.com/poco-c31-royal-blue-6...
# 23  https://www.flipkart.com/apple-iphone-12-mini-...

# %%
# exporting the above dataframe in csv format 
phone_df.to_csv(r"C:\Users\DELL\DS Task\smartphone_details_from_flipkart.csv", index=False)

# %%
# obtaining the web page details with the given url
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# obtaining the web page with the provided url
url="https://www.google.co.in/maps"
driver.get(url)
srch_box = driver.find_element_by_class_name("tactile-searchbox-input")  # getting the search bar
place = str(input("Enter the place name which you want to search on Google Maps: "))  # taking input from user to search for location
srch_box.send_keys(place)    
submit = driver.find_element_by_class_name("nhb85d-BIqFsb")
submit.click()  # clicking on the search button
current_url = driver.current_url   # coordinates are presents in the URL so fetching current url

import re

try:
    lat = re.findall('(\d+(\.\d*)?)', current_url)[0]   # fetching the latitude data
    lon = re.findall('(\d+(\.\d*)?)', current_url)[1]  # fetching the longitude data
    print("Geospatial Coordinates for", place + " on Google Maps are: ")
    print("Latitude  :", lat[0])
    print("Longitude :", lon[0])
    
except Exception as e:
    print("Error: ", str(e))
# Out:
# <ipython-input-23-778dad0dcdbe>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# <ipython-input-23-778dad0dcdbe>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   srch_box = driver.find_element_by_class_name("tactile-searchbox-input")  # getting the search bar
# Enter the place name which you want to search on Google Maps: vijayawada
# <ipython-input-23-778dad0dcdbe>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   submit = driver.find_element_by_class_name("nhb85d-BIqFsb")
# Geospatial Coordinates for vijayawada on Google Maps are:
# Latitude  : 16.4833766
# Longitude : 80.6881609

# %%
#loading the driver and the url
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
driver.get('https://trak.in/')
time.sleep(2)

driver.get(driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href'))
# Out:
# <ipython-input-24-7d1db70a9549>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# <ipython-input-24-7d1db70a9549>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.get(driver.find_element_by_xpath('//li[@id="menu-item-51510"]/a').get_attribute('href'))

# %%
#creating the empty list 
date=[]
name=[]
industry=[]
sub=[]
city=[]
investor=[]
inv_type=[]
amount=[]

#scrapping for date
for i in driver.find_elements_by_xpath('//td[@class="column-2"]'):
    date.append(i.text)

#scrapping for name
for i in driver.find_elements_by_xpath('//td[@class="column-3"]'):
    name.append(i.text)

#scrapping for industry    
for i in driver.find_elements_by_xpath('//td[@class="column-4"]'):
    industry.append(i.text)

#scrapping for sub industry
for i in driver.find_elements_by_xpath('//td[@class="column-5"]'):
    sub.append(i.text)

#scrapping for city    
for i in driver.find_elements_by_xpath('//td[@class="column-6"]'):
    city.append(i.text)

#scrapping for investor
for i in driver.find_elements_by_xpath('//td[@class="column-7"]'):
    investor.append(i.text)

#scrapping for investor type    
for i in driver.find_elements_by_xpath('//td[@class="column-8"]'):
    inv_type.append(i.text)

#scrapping for amount
for i in driver.find_elements_by_xpath('//td[@class="column-9"]'):
    amount.append(i.text)
# Out:
# <ipython-input-26-dd32ee250c50>:12: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-2"]'):
# <ipython-input-26-dd32ee250c50>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-3"]'):
# <ipython-input-26-dd32ee250c50>:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-4"]'):
# <ipython-input-26-dd32ee250c50>:24: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-5"]'):
# <ipython-input-26-dd32ee250c50>:28: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-6"]'):
# <ipython-input-26-dd32ee250c50>:32: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-7"]'):
# <ipython-input-26-dd32ee250c50>:36: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-8"]'):
# <ipython-input-26-dd32ee250c50>:40: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath('//td[@class="column-9"]'):

# %%
#creating the dataframe for Jan-Mar
Funding={'Date':date,'Name':name,'Industry/Vertica':industry,'Sub-vertical':sub,'City':city,'Investor':investor,
        'Investment Type':inv_type,'Amount':amount}
Funding=pd.DataFrame(data=Funding)
Funding[5:29]
# Out:
#           Date                    Name        Industry/Vertica  \
# 5   04/03/2021               DealShare              E-commerce
# 6   31/03/2021                Uniphore              Technology
# 7   30/03/2021                   Dunzo              E-commerce
# 8   30/03/2021                  BYJU’S                Edu-tech
# 9   23/03/2021             SkilloVilla                Edu-tech
# 10  25/03/2021                CityMall              E-commerce
# 11  26/03/2021                   DotPe                 FinTech
# 12  11/02/2021                Doubtnut                Edu Tech
# 13  22/02/2021                  Zomato             Hospitality
# 14  19/02/2021               Fingerlix             Hospitality
# 15  17/02/2021                   Zolve                 FinTech
# 16  15/02/2021               KreditBee                 Finance
# 17  12/02/2021               Pepperfry              E-commerce
# 18  12/02/2021                 Grofers              E-Commerce
# 19  09/02/2021                 Nothing              Technology
# 20  09/02/2021             SplashLearn                  EdTech
# 21  15/01/2021         Digit Insurance      Financial Services
# 22  28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 23  19/01/2021                  DeHaat        AgriTech Startup
# 24  19/01/2021               Darwinbox                    SaaS
# 25  18/01/2021                   mfine     Health Tech Startup
# 26  18/01/2021                   Udayy                  EdTech
# 27  11/01/2021           True Elements            Food Startup
# 28  13/01/2021                   Saveo          B2B E-commerce
#
#                                          Sub-vertical               City  \
# 5                            Online shopping platform  Jaipur, Rajasthan
# 6             Conversational Service Automation (CSA)          Palo Alto
# 7                            Hyper-local delivery app          Bengaluru
# 8                                     Online tutoring          Bengaluru
# 9                 Career and job-oriented upskilling.          Bengaluru
# 10       Social ecommerce and online grocery platform            Gurgaon
# 11  Commerce and payments platform to offline ente...            Gurgaon
# 12                                E-Learning Platform            Gurgaon
# 13                      Online Food Delivery Platform            Gurgaon
# 14                      Semi-cooked food delivery app             Mumbai
# 15                             Global Neobank Venture             Mumbai
# 16                           Digital lending platform          Bengaluru
# 17                        Multi-brand furniture brand             Mumbai
# 18                                 Online supermarket            Gurgaon
# 19                        Consumer Technology Venture             London
# 20                      Game-based learning programme            Gurgaon
# 21                                 Insurance Services          Bengaluru
# 22      Shave care, beard care, and skincare products          New Delhi
# 23  online marketplace for farm products and services              Patna
# 24                                            HR Tech             Mumbai
# 25                 AI-powered telemedicine mobile app          Bengaluru
# 26     Online learning platform for kids in class 1-5            Gurgaon
# 27                      Whole Food plant based Nashta               Pune
# 28                                         Pharmacies          Bengaluru
#
#                                              Investor Investment Type  \
# 5                                     Innoven Capital  Debt Financing
# 6                           Sorenson Capital Partners        Series D
# 7                           Krishtal Advisors Pte Ltd        Series E
# 8          MC Global Edtech, B Capital, Baron, others        Series F
# 9                               Titan Capital, others            Seed
# 10                                     Accel Partners        Series A
# 11                                               PayU        Series A
# 12  SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 13                                 Tiger Global, Kora         Venture
# 14           Rhodium Trust, Accel Partners and Swiggy        Series C
# 15     Accel Partners and Lightspeed Venture Partners            Seed
# 16  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 17                                    InnoVen Capital  Debt Financing
# 18                         SoftBank Vision Fund (SVF)     Unspecified
# 19                                                 GV        Series A
# 20                                       Owl Ventures        Series C
# 21   A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 22                                  Reckitt Benckiser         Venture
# 23                                    Prosus Ventures        Series C
# 24                                Salesforce Ventures            Seed
# 25                         Heritas Capital Management   Venture Round
# 26                                    Sequoia Capital    Seed Funding
# 27                              SIDBI Venture Capital          Series
# 28          Matrix Partners India, RTP Global, others            Seed
#
#           Amount
# 5    250,000,000
# 6    140,000,000
# 7      8,000,000
# 8    460,000,000
# 9    300,000,000
# 10    11,000,000
# 11    27,500,000
# 12     2,500,000
# 13   250,000,000
# 14  2,747,045.20
# 15   1,50,00,000
# 16    75,000,000
# 17     4,773,958
# 18    55,000,000
# 19    15,000,000
# 20    18,000,000
# 21   1,80,00,000
# 22  6,172,258.50
# 23    30,000,000
# 24    15,000,000
# 25    16,000,000
# 26    15,000,000
# 27   100,000,000
# 28     4,000,000

# %%
#loading the driver and the url
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
url = "https://www.digit.in/"
driver.get(url)
time.sleep(3)

# now we will search for best gaming laptops
best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
time.sleep(4)

# creating empty lists to store all gaming laptop information
lap_name = []
op_stm = []
display = []
processor = []
memory = []
weight = []
dimensions = []
graph_processor = []
prices = []

# fetching the laptop names
name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
for i in name:
    lap_name.append(i.text)
    
# fetching information related to operating system
try:
    os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
    for i in os:
        op_stm.append(i.text)
except NoSuchElementException:
    pass

# fetching information for display
try:
    disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
    for i in disp:
        display.append(i.text)
except NoSuchElementException:
    pass

# fetching information for processor
try:
    pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
    for i in pro:
        processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for memory
try:
    mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
    for i in mem:
        memory.append(i.text)
except NoSuchElementException:
    pass

# fetching information for weight
try:
    wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
    for i in wgt:
        weight.append(i.text)
except NoSuchElementException:
    pass

# fetching information for dimensions
try:
    dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
    for i in dim:
        dimensions.append(i.text)
except NoSuchElementException:
    pass

# fetching information for graphic processor
try:
    g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
    for i in g_pro:
        graph_processor.append(i.text)
except NoSuchElementException:
    pass

# fetching information for price
try:
    price = driver.find_elements_by_xpath("//td[@class='smprice']")
    for i in price:
        prices.append(i.text.replace('₹','Rs '))
except NoSuchElementException:
    pass

# now creating a dataframe from all the collected details
data = list(zip(lap_name,op_stm,display,processor,memory,weight,dimensions,graph_processor,prices))
laptop_df = pd.DataFrame(data, columns = ["Laptop Name","Operating System","Display","Processor","Memory",
                                   "Weight(Kg)","Dimensions","Graphic-Processor","Price"])
laptop_df
# Out:
# <ipython-input-34-b3be49d11691>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# <ipython-input-34-b3be49d11691>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   best_gaming_lap = driver.find_element_by_xpath("//div[@class='listing_container']//ul//li[9]").click()
# <ipython-input-34-b3be49d11691>:23: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//table[@id='summtable']//tr//td[1]")
# <ipython-input-34-b3be49d11691>:29: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[3]//td[3]")
# <ipython-input-34-b3be49d11691>:37: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   disp = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[4]//td[3]")
# <ipython-input-34-b3be49d11691>:45: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[5]//td[3]")
# <ipython-input-34-b3be49d11691>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   mem = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[6]//td[3]")
# <ipython-input-34-b3be49d11691>:61: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   wgt = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[7]//td[3]")
# <ipython-input-34-b3be49d11691>:69: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dim = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[8]//td[3]")
# <ipython-input-34-b3be49d11691>:77: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   g_pro = driver.find_elements_by_xpath("//div[@class='Spcs-details']//tr[9]//td[3]")
# <ipython-input-34-b3be49d11691>:85: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   price = driver.find_elements_by_xpath("//td[@class='smprice']")
#                                      Laptop Name Operating System  \
# 0                    Acer NITRO 5 Ryzen 9 (2021)       Windows 10
# 1  MSI Stealth 15M 11th Gen Core i7-11375H (2021       Windows 10
# 2   ASUS ROG Strix Scar 15 Ryzen 9-5900HX (2021)       Windows 10
# 3                          Alienware Area 51M R2  Windows 10 Home
# 4                               Alienware m15 R3  Windows 10 Home
# 5                         ASUS ROG Strix Scar 15  Windows 10 Home
# 6                          Asus ROG Zephyrus G14  Windows 10 Home
# 7                               Lenovo Legion 5i   Windows 10 Pro
# 8                       ASUS ROG ZEPHYRUS DUO 15       Windows 10
# 9                           Acer Aspire 7 gaming  Windows 10 Home
#
#                Display                                   Processor  \
# 0  15.6" (1920 x 1080)             AMD Ryzen 9 Octa Core | 2.4 GHz
# 1  15.6" (1920 x 1080)        Intel Core i7 11th Gen - 11375H | NA
# 2  15.6" (2560 x 1440)    AMD Ryzen 9 Octa Core - 5900HX | 3.3 GHz
# 3  17.3" (1920 x 1080)   10th Gen Intel® Core™ i7-10700 | 2.90 GHz
# 4  15.6" (3840 x 2160)       10th Gen Intel® Core™ i9-10980HK | NA
# 5  15.6" (1920 x 1080)               AMD Ryzen™ 9 5900HX | 3.3 GHz
# 6    14" (1920 x 1080)               AMD 3rd Gen Ryzen 9 | 3.3 GHz
# 7  15.6" (1920 x 1080)  10th Gen Intel® Core™ i5-10300H | 2.50 GHz
# 8  15.6" (3840 x 1100)          Intel Core i7 10th Gen 10875H | NA
# 9  15.6" (1920 x 1080)           AMD Ryzen™ 5-5500U hexa-core | NA
#
#                    Memory Weight(Kg)               Dimensions  \
# 0   1 TB HDD/16 GBGB DDR4        2.4       363.4 x 255 x 23.9
# 1   1 TB SSD/16 GBGB DDR4        1.7      358.3 x 248 x 16.15
# 2   2 TB SSD/32 GBGB DDR4       2.30         354 x 259 x 22.6
# 3   1 TB SSD/16 GBGB DDR4        4.1   27.65 x 402.6 x 319.14
# 4   1 TB SSD/16 GBGB DDR4         NA                       NA
# 5   1 TB SSD/16 GBGB DDR4       2.30       35.4 x 25.9 x 2.26
# 6   1 TB SSD/16 GBGB DDR4       1.65        32.5 x 22.1 x 1.8
# 7   1 TB SSD/16 GBGB DDR4        2.3  363.06 x 259.61 x 23.57
# 8  512 GB SSD/4 GBGB DDR4        2.4  268.30 x 360.00 x 20.90
# 9  512 GB SSD/8 GBGB DDR4       2.15       2.29 x 36.3 x 25.4
#
#                Graphic-Processor        Price
# 0        NVIDIA GeForce RTX 3070  Rs  129,990
# 1        NVIDIA GeForce RTX 3060  Rs  134,990
# 2        NVIDIA GeForce RTX 3080  Rs  268,990
# 3        Intel® UHD Graphics 630  Rs  342,989
# 4                             NA  Rs  319,990
# 5      NVIDIA® GeForce RTX™ 3070  Rs  215,990
# 6        NVIDIA GeForce RTX 2060  Rs  164,990
# 7  NVIDIA® GeForce® GTX 1650 4GB   Rs  76,988
# 8  NVIDIA GeForce RTX 2070 Max-Q  Rs  185,000
# 9      NVIDIA® GeForce® GTX 1650   Rs  58,499

# %%
#loading the driver and the url
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
url = 'https://www.forbes.com/'
driver.get(url)
time.sleep(3)

# clicking on the hamburger option on the left side of the page
optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
optn.click()
time.sleep(1)

# now clicking on the 'Billionaires' option
bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
bill.click()
time.sleep(1)

# finally clicking on the 'World Billionaire' option after the mouse hover
world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
world_bill.click()
time.sleep(1)
# Out:
# <ipython-input-35-f4f8eba5e272>:2: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# <ipython-input-35-f4f8eba5e272>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   optn = driver.find_element_by_xpath("//button[@class='icon--hamburger']")
# <ipython-input-35-f4f8eba5e272>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]")
# <ipython-input-35-f4f8eba5e272>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   world_bill = driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")

# %%
# fetching the rank
rank = []
try:
    rnk = driver.find_elements_by_xpath("//div[@class='rank']")
    for i in rnk:
        rank.append(i.text)
except NoSuchElementException:
    pass

# fetching the names of the billionaires
names = []
try:
    name = driver.find_elements_by_xpath("//div[@class='personName']")
    for i in name:
        names.append(i.text)
except NoSuchElementException:
    pass

# fetching the total net worth
net_worth = []
try:
    worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
    for i in worth:
        net_worth.append(i.text)
except NoSuchElementException:
    pass

# fetching the age of the billionaires
Age = []
try:
    age = driver.find_elements_by_xpath("//div[@class='age']")
    for i in age:
        Age.append(i.text)
except NoSuchElementException:
    Age.append('-')
    
# fetching the citizenship of the billionaires
citizenship = []
try:
    cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
    for i in cit:
        citizenship.append(i.text)
except NoSuchElementException:
    citizenship.append('-')
    
# fetching the source of incomes for the billionaires
source = []
try:
    src = driver.find_elements_by_xpath("//div[@class='source-column']")
    for i in src:
        source.append(i.text)
except NoSuchElementException:
    source.append('-')
    
# fetching the industry in which the billionaires are prominent
industry = []
try:
    ind = driver.find_elements_by_xpath("//div[@class='category']")
    for i in ind:
        industry.append(i.text)
except NoSuchElementException:
    industry.append('-')
    
# now creating a dataframe from all the collected information
data = list(zip(rank,names,net_worth,Age,citizenship,source,industry))
forbes_df = pd.DataFrame(data, columns = ["Rank", "Name", "Net worth", "Age", "Citizenship", "Source","Industry"])
forbes_df
# Out:
# <ipython-input-36-60a766140d44>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   rnk = driver.find_elements_by_xpath("//div[@class='rank']")
# <ipython-input-36-60a766140d44>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//div[@class='personName']")
# <ipython-input-36-60a766140d44>:22: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   worth = driver.find_elements_by_xpath("//div[@class='netWorth']")
# <ipython-input-36-60a766140d44>:31: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   age = driver.find_elements_by_xpath("//div[@class='age']")
# <ipython-input-36-60a766140d44>:40: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   cit = driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
# <ipython-input-36-60a766140d44>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   src = driver.find_elements_by_xpath("//div[@class='source-column']")
# <ipython-input-36-60a766140d44>:58: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath("//div[@class='category']")
#      Rank                      Name Net worth Age    Citizenship  \
# 0      1.                Jeff Bezos    $177 B  57  United States
# 1      2.                 Elon Musk    $151 B  49  United States
# 2      3.  Bernard Arnault & family    $150 B  72         France
# 3      4.                Bill Gates    $124 B  65  United States
# 4      5.           Mark Zuckerberg     $97 B  36  United States
# ..    ...                       ...       ...  ..            ...
# 195  195.           Harry Triguboff   $11.2 B  88      Australia
# 196  197.     Leonid Fedun & family   $11.1 B  65         Russia
# 197  197.                 Eyal Ofer   $11.1 B  70         Israel
# 198  197.              Evan Spiegel   $11.1 B  30  United States
# 199  200.     Luis Carlos Sarmiento     $11 B  88       Colombia
#
#                     Source               Industry
# 0                   Amazon             Technology
# 1            Tesla, SpaceX             Automotive
# 2                     LVMH       Fashion & Retail
# 3                Microsoft             Technology
# 4                 Facebook             Technology
# ..                     ...                    ...
# 195            real estate            Real Estate
# 196                    oil                 Energy
# 197  real estate, shipping            Diversified
# 198               Snapchat             Technology
# 199                banking  Finance & Investments
#
# [200 rows x 7 columns]

# %%
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# obtaining the web page with given url
url = "https://www.youtube.com/watch?v=mSxeQoJgPw0"
driver.get(url)
# Out:
# <ipython-input-40-d5cc3c0c6184>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")

# %%
# we are going to scroll through the comments
for i in range(1000):
    driver.execute_script("window.scrollBy(0,100)")

# %%
# creating empty lists to store the required information
comments = []
upvotes = []
times = []

# fetching all the comments
try:
    comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
    for i in comment:
        comments.append(i.text)
except NoSuchElementException:
    comments.append('-')
time.sleep(5)

# fetching all the upvotes
try:
    up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
    for i in up:
        upvotes.append(i.text)
except NoSuchElementException:
    upvotes.append('-')
time.sleep(5)

# fetching all the time information indicating when the comment was made
try:
    timing = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
    for i in timing:
        times.append(i.text.replace('(edited)',''))
except NoSuchElementException:
    times.append('-')
time.sleep(5)

# now we are creating a dataframe from the accumulated information
data = list(zip(comments,upvotes,times))
comment_df = pd.DataFrame(data, columns = ["Comment","Upvotes","Published time"])
comment_df
# Out:
# <ipython-input-42-28e1b0bf1e70>:8: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   comment = driver.find_elements_by_xpath("//*[@id='content-text']")[:500]
# <ipython-input-42-28e1b0bf1e70>:17: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   up = driver.find_elements_by_xpath("//*[@id='vote-count-middle']")[:500]
# <ipython-input-42-28e1b0bf1e70>:26: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   timing = driver.find_elements_by_xpath("//yt-formatted-string[@class='published-time-text above-comment style-scope ytd-comment-renderer']")[:500]
#                                                Comment Upvotes Published time
# 0    Have you always wanted to see Bassjackers live...     142    2 years ago
# 1    a really great track and a good collab between...      46    5 years ago
# 2    Llevo años literalmente buscando esta canción ...      26     1 year ago
# 3    KSHMR is so amazing. He is the only DJ/Produce...     137    5 years ago
# 4             This is such an underrated song of KSHMR     151    2 years ago
# ..                                                 ...     ...            ...
# 495                                              Fire        1    5 years ago
# 496                                So Beautiful... :'3            5 years ago
# 497             Finally found this song after 2 months       1    3 years ago
# 498              Here before 1Million and 1 Billion ;)       3    5 years ago
# 499  FACCIAMO CAPIRE CHE ANCHE IN ITALIA AMIAMO KSH...            5 years ago
#
# [500 rows x 3 columns]

# %%
driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")
# obtaining the web page from the given url
url = "https://www.hostelworld.com/"
driver.get(url)
# Out:
# <ipython-input-57-399f1200bcf3>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Edge(r"C:/Users/DELL/Downloads/edgedriver_win64/msedgedriver.exe")

# %%
#entering the city name in search bar
driver.find_element_by_xpath("//input[@id='search-input-field']").send_keys('London')
# Out:
# <ipython-input-59-1e6ad2f81486>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//input[@id='search-input-field']").send_keys('London')

# %%
button = driver.find_element_by_xpath("//div[@class='label']")
button.click()
# Out:
# <ipython-input-60-8a25f7f80e30>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = driver.find_element_by_xpath("//div[@class='label']")

# %%
search_button = driver.find_element_by_id('search-button')
search_button.click()
# Out:
# <ipython-input-61-18c62b26d0c5>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button = driver.find_element_by_id('search-button')

# %%
# creating empty lists to collect the required information
hostel_name = []
distance = []
pvt_prices = []
dorms_price = []
rating = []
reviews = []
over_all = []
facilities = []
description =[]
product_url = []

for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
    i.click()
    time.sleep(4)
    
    # fetching hostel name
    try:
        name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
        for i in name:
            hostel_name.append(i.text)
    except NoSuchElementException:
        hostel_name.append('-')
        
    # fetching the distance from city centre    
    try:
        dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
        for i in dist:
            distance.append(i.text.replace('Hostel - ',''))
    except NoSuchElementException:
        distance.append('-')
        
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        
    # fetching the privates from price details
        try:
            pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
            pvt_prices.append(pvt_price.text)
        except NoSuchElementException:
            pvt_prices.append('-')
            
    # fetching the dorms from price information
    for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
        try:
            dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
            dorms_price.append(dorms.text)
        except NoSuchElementException:
            dorms_price.append('-')
            
    # fetching all the facilities
    try:
        fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
        fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
        for i in fac1:
            for j in fac2:
                facilities.append(i.text +', '+ j.text )
    except NoSuchElementException:
        facilities.append('-')
        
    # fetching the urls of each hostel
    p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
    for i in p_url:
        product_url.append(i.get_attribute('href'))

for i in product_url:
    driver.get(i)
    time.sleep(3)
    
    # clicking on the show more button for description
    try:
        driver.find_element_by_xpath("//a[@class='toggle-content']").click()
        time.sleep(5)
    except NoSuchElementException:
        pass
    
    # fetching the ratings for the hostels
    try:
        rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
        rating.append(rat.text)
    except NoSuchElementException:
        rating.append('-')
        
    # fetching the total reviews        
    try:
        rws = driver.find_element_by_xpath("//div[@class='reviews']")
        reviews.append(rws.text.replace('Total Reviews',''))
    except NoSuchElementException:
        reviews.append('-')
        
    # fetching the overall review
    try:
        overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
        over_all.append(overall_rw.text)
    except NoSuchElementException:
        over_all.append('-')
        
    # fetching the property description 
    try:
        disc = driver.find_element_by_xpath("//div[@class='content']")
        description.append(disc.text)
    except NoSuchElementException:
        over_all.append('-')

# now creating a pandas dataframe to show all the collected data
data = list(zip(hostel_name,distance,rating,reviews,over_all,pvt_prices,dorms_price,facilities,description))       
hotel_df = pd.DataFrame(data, columns = ["Hostel name","Distance from city centre","ratings","Total reviews",
                                   "Overall review","Privates from price","Dorms from price","Facilities","Property Description"])
hotel_df
# Out:
# <ipython-input-62-9253bc8dabb2>:13: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class = 'pagination-item pagination-current' or @class='pagination-item']"):
# <ipython-input-62-9253bc8dabb2>:19: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   name = driver.find_elements_by_xpath("//h2[@class='title title-6']")
# <ipython-input-62-9253bc8dabb2>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dist = driver.find_elements_by_xpath("//div[@class='subtitle body-3']//a//span[1]")
# <ipython-input-62-9253bc8dabb2>:33: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
# <ipython-input-62-9253bc8dabb2>:37: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   pvt_price = driver.find_element_by_xpath("//a[@class='prices']//div[1]//div")
# <ipython-input-62-9253bc8dabb2>:43: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   for i in driver.find_elements_by_xpath("//div[@class='prices-col']"):
# <ipython-input-62-9253bc8dabb2>:45: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   dorms = driver.find_element_by_xpath("//a[@class='prices']//div[2]//div")
# <ipython-input-62-9253bc8dabb2>:52: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fac1 = driver.find_elements_by_xpath("//div[@class='has-wifi']")
# <ipython-input-62-9253bc8dabb2>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   fac2 = driver.find_elements_by_xpath("//div[@class='has-sanitation']")
# <ipython-input-62-9253bc8dabb2>:61: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   p_url = driver.find_elements_by_xpath("//div[@class='prices-col']//a[2]")
# <ipython-input-62-9253bc8dabb2>:71: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath("//a[@class='toggle-content']").click()
# <ipython-input-62-9253bc8dabb2>:78: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rat = driver.find_element_by_xpath("//div[@class='score orange big' or @class='score gray big']")
# <ipython-input-62-9253bc8dabb2>:85: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   rws = driver.find_element_by_xpath("//div[@class='reviews']")
# <ipython-input-62-9253bc8dabb2>:92: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   overall_rw = driver.find_element_by_xpath("//div[@class='keyword']//span")
# <ipython-input-62-9253bc8dabb2>:99: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disc = driver.find_element_by_xpath("//div[@class='content']")
#                     Hostel name                   Distance from city centre  \
# 0             Mornington Camden                      4.1km from city centre
# 1   Smart Russell Square Hostel                      2.6km from city centre
# 2       Smart Camden Inn Hostel                      4.4km from city centre
# 3                 Selina Camden                      5.5km from city centre
# 4       Queen Elizabeth Chelsea                      5.7km from city centre
# ..                          ...                                         ...
# 89                  Green Rooms             Hotel - 10.8km from city centre
# 90             23 Matheson Road  Bed and Breakfast - 6.2km from city centre
# 91             Park Hotel Essex             Hotel - 24.1km from city centre
# 92              Cranbrook Hotel             Hotel - 14.8km from city centre
# 93       TLK Apartments & Hotel             Hotel - 19.9km from city centre
#
#    ratings Total reviews Overall review Privates from price Dorms from price  \
# 0      8.3           44        Fabulous              Rs3782           Rs2580
# 1      6.7         9561            Good              Rs3782           Rs2580
# 2      8.4         2731        Fabulous              Rs3782           Rs2580
# 3      9.1           13          Superb              Rs3782           Rs2580
# 4      7.5         3212       Very Good              Rs3782           Rs2580
# ..     ...           ...            ...                 ...              ...
# 89     9.7           76          Superb              Rs3722           Rs2463
# 90       -            0       No Rating              Rs5030                -
# 91     8.0          109        Fabulous              Rs5030                -
# 92       -            0       No Rating              Rs5030                -
# 93       -            0       No Rating              Rs5030                -
#
#                                          Facilities  \
# 0   Free WiFi, Follows Covid-19 sanitation guidance
# 1   Free WiFi, Follows Covid-19 sanitation guidance
# 2   Free WiFi, Follows Covid-19 sanitation guidance
# 3   Free WiFi, Follows Covid-19 sanitation guidance
# 4   Free WiFi, Follows Covid-19 sanitation guidance
# ..                                              ...
# 89  Free WiFi, Follows Covid-19 sanitation guidance
# 90  Free WiFi, Follows Covid-19 sanitation guidance
# 91  Free WiFi, Follows Covid-19 sanitation guidance
# 92  Free WiFi, Follows Covid-19 sanitation guidance
# 93  Free WiFi, Follows Covid-19 sanitation guidance
#
#                                  Property Description
# 0                   2 Hurdwick Place, London, England
# 1                 71 Guilford Street, London, England
# 2        55/57 Bayham Street, Camden, London, England
# 3       89 Chalk Farm Rd, Chalk Farm, London, England
# 4                    58 Bagleys Lane, London, England
# ..                                                ...
# 89    13-27 Station Road, Wood Green, London, England
# 90                  23 Matheson Road, London, England
# 91        327 Cranbrook Road, Ilford, London, England
# 92       22/24 Coventry Road, Ilford, London, England
# 93  36-40 High Street, TLK Apartments & Hotel, Lon...
#
# [94 rows x 9 columns]
